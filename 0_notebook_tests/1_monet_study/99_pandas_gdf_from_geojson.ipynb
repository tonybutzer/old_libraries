# %%
import geopandas as gpd

# %%
gdf = gpd.read_file("imagery.geojson")

# %%
gdf
# Out:
#                     datetime     platform constellation instruments  gsd  \
# 0  2020-12-28 17:31:40+00:00  sentinel-2b    sentinel-2       [msi]   10
# 1  2020-12-08 17:31:40+00:00  sentinel-2b    sentinel-2       [msi]   10
# 2  2020-11-28 17:31:42+00:00  sentinel-2b    sentinel-2       [msi]   10
# 3  2020-11-08 17:31:44+00:00  sentinel-2b    sentinel-2       [msi]   10
# 4  2020-11-03 17:31:47+00:00  sentinel-2a    sentinel-2       [msi]   10
# 5  2020-10-29 17:31:45+00:00  sentinel-2b    sentinel-2       [msi]   10
# 6  2020-10-09 17:31:46+00:00  sentinel-2b    sentinel-2       [msi]   10
# 7  2020-10-04 17:31:48+00:00  sentinel-2a    sentinel-2       [msi]   10
# 8  2020-09-29 17:31:45+00:00  sentinel-2b    sentinel-2       [msi]   10
# 9  2020-09-24 17:31:48+00:00  sentinel-2a    sentinel-2       [msi]   10
# 10 2020-09-19 17:31:44+00:00  sentinel-2b    sentinel-2       [msi]   10
# 11 2020-09-14 17:31:46+00:00  sentinel-2a    sentinel-2       [msi]   10
# ...
