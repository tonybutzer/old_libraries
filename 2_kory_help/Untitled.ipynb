# %%
! conda list | grep make

# %%
! which python
# Out:
# /srv/conda/envs/pangeo/bin/python

# %%
# !conda list
# Out:
# # packages in environment at /srv/conda/envs/pangeo:
# #
# # Name                    Version                   Build  Channel
# _libgcc_mutex             0.1                 conda_forge    conda-forge
# _openmp_mutex             4.5                       2_gnu    conda-forge
# adal                      1.2.7              pyhd8ed1ab_0    conda-forge
# adlfs                     2022.11.2          pyhd8ed1ab_0    conda-forge
# adwaita-icon-theme        41.0                 ha770c72_1    conda-forge
# affine                    2.3.1              pyhd8ed1ab_0    conda-forge
# aiobotocore               2.4.0              pyhd8ed1ab_0    conda-forge
# aiofiles                  22.1.0             pyhd8ed1ab_0    conda-forge
# aiohttp                   3.8.3            py39hb9d737c_1    conda-forge
# aiohttp-client-cache      0.8.1              pyhd8ed1ab_2    conda-forge
# aioitertools              0.11.0             pyhd8ed1ab_0    conda-forge
# ...
